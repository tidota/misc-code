# %% [markdown]
# # Simplest simulation of confidence reduction
#
# - Two estimators
# - Each one has a probability distribution
# - They exchange their estimates
#     - by the naive
#     - by the conservative data exchange
# - What if they repeated the exchange multiple times?
# - What if the exchanged data gains some noises?

# %%
import random
import math
import matplotlib.pyplot as plt
import statistics
import numpy as np

# %% [markdown]
# ## make two distributions

# %%
x_max = 100
x_min = 0
dlt = 0.1
N = int((x_max-x_min)/dlt)
print('N: ' + str(N))
x_axis = [x_min + i * dlt for i in range(N)]

def p(x, mean, sigma):
    return math.exp(-0.5*(x - mean)**2 / sigma / sigma) / math.sqrt(2*math.pi*sigma*sigma)


dist1 = [p(x, 50, 10) for x in x_axis]
print('sum1: ' + str(sum(dist1)*dlt))
dist2 = [p(x, 50, 10) for x in x_axis]
print('sum2: ' + str(sum(dist2)*dlt))

plt.scatter(x_axis, dist1)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(dist1)*dlt))
plt.scatter(x_axis, dist2)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(dist2)*dlt))
# Out:
# N: 1000
# sum1: 0.9999994265729685
# sum2: 0.9999994265729685
# max at 50.0
# max at 50.0

# %% [markdown]
# # interaction functions

# %%
def combine(p1, p2, off = 0):
    ans = []
    for i in range(len(p1)):
        if i + off < 0:
            ans.append(p1[i]*p2[0])
        elif len(p2) <= i + off:
            ans.append(p1[i]*p2[-1])
        else:
            ans.append(p1[i]*p2[i+off])
#     temp_min = -1
#     for i in range(len(ans)):
#         if ans[i] != 0 and (temp_min -1 or temp_min > ans[i]):
#             temp_min = ans[i]
#     for i in range(len(ans)):
#         if ans[i] == 0:
#             ans[i] = temp_min/1000.0
    total = sum(ans)*dlt
    for i in range(len(ans)):
        ans[i] /= total
    return ans

def divide(p, omega):
    ans1 = []
    ans2 = []
    for i in range(len(p)):
        ans1.append(math.pow(p[i], omega))
        ans2.append(math.pow(p[i], 1-omega))
    total1 = sum(ans1)*dlt
    total2 = sum(ans2)*dlt
    for i in range(len(ans1)):
        ans1[i] /= total1
        ans2[i] /= total2
    return [ans1, ans2]

p_comb = combine(dist1, dist2)
print(sum(p_comb)*dlt)
plt.scatter(x_axis, p_comb)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(p_comb)*dlt))
# p1, p2 = divide(p, 0.4)
# print(sum(p1)*dlt)
# print(sum(p2)*dlt)
# plt.scatter(x_axis, p1)
# plt.xlim(x_min, x_max)
# plt.show()
# plt.scatter(x_axis, p2)
# plt.xlim(x_min, x_max)
# plt.show()
# Out:
# 0.9999999999999982
# max at 50.0

# %% [markdown]
# # repeated interactions

# %%
n_interactions = 1000

# %% [markdown]
# ## Naive

# %%
p1 = list(dist1)
p2 = list(dist2)
for i in range(n_interactions):
    p1 = combine(p1, p2)
    p2 = list(p1)

print(sum(p1)*dlt)
print(sum(p2)*dlt)
plt.scatter(x_axis, p1)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(p1)*dlt))
plt.scatter(x_axis, p2)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(p2)*dlt))
# Out:
# 0.9999999999999999
# 0.9999999999999999
# max at 50.0
# max at 50.0

# %% [markdown]
# # Conservative

# %%
p1 = list(dist1)
p2 = list(dist2)
omega = 0.9
for i in range(n_interactions):
    p1_omega, p1_1_omega = divide(p1, omega)
    p2_omega, p2_1_omega = divide(p2, omega)
    p1 = combine(p1_omega, p2_1_omega)
    p2 = combine(p2_omega, p1_1_omega)

print(sum(p1)*dlt)
print(sum(p2)*dlt)
plt.scatter(x_axis, p1)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(p1)*dlt))
plt.scatter(x_axis, p2)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(p2)*dlt))
# Out:
# 1.0000000000000007
# 1.0000000000000007
# max at 50.0
# max at 50.0

# %% [markdown]
# # noises

# %%
noise_sigma = 3
noise_mean = (x_min+x_max)/2.0
p_noise = [p(x, noise_mean, noise_sigma) for x in x_axis]
noise_mean_indx = len(p_noise)//2
plt.scatter(x_axis, p_noise)
plt.xlim(x_min, x_max)
plt.show()
print(sum(p_noise)*dlt)
# Out:
# 1.000000000000001

# %% [markdown]
# # Convolution

# %%
def conv(p1, p2, position):
    ans = [0] * len(p1)
    for i in range(len(p1)):
        for j in range(len(p2)):
            k = j - i + position
            if 0 <= k and k < len(p2):
                ans[i] += p1[j] * p2[k]
    total = sum(ans)*dlt
    for i in range(len(ans)):
        ans[i] /= total
    return ans

p1_conv = conv(dist1, p_noise, noise_mean_indx)
plt.scatter(x_axis, p1_conv)
plt.xlim(x_min, x_max)
plt.show()
print(sum(p1_conv)*dlt)
p2_conv = conv(dist2, p_noise, noise_mean_indx)
plt.scatter(x_axis, p2_conv)
plt.xlim(x_min, x_max)
plt.show()
print(sum(p2_conv)*dlt)


noise = random.gauss((x_min+x_max)/2.0, noise_sigma)
print('noise: ' + str(noise))
print('off: ' + str(int((noise-noise_mean)/dlt+0.5)) + ' for ' + str(len(dist1)))

p1_comb = combine(dist1, p2_conv, int((noise-noise_mean)/dlt+0.5))
plt.scatter(x_axis, p1_comb)
plt.xlim(x_min, x_max)
plt.show()
print(sum(p1_comb)*dlt)
print("max at " + str(np.argmax(p1_comb)*dlt))

p2_comb = combine(dist2, p1_conv, int(-(noise-noise_mean)/dlt+0.5))
plt.scatter(x_axis, p2_comb)
plt.xlim(x_min, x_max)
plt.show()
print(sum(p2_comb)*dlt)
print("max at " + str(np.argmax(p2_comb)*dlt))

p_comb = combine(p1_conv, p2_conv)
plt.scatter(x_axis, p_comb)
plt.xlim(x_min, x_max)
plt.show()
print(sum(p_comb)*dlt)
print("max at " + str(np.argmax(p_comb)*dlt))
# Out:
# 1.0000000000000022
# 1.0000000000000022
# noise: 47.649653300433236
# off: -23 for 1000
# 1.0000000000000013
# max at 51.1
# 1.0000000000000016
# max at 48.900000000000006
# 0.9999999999999997
# max at 50.0

# %% [markdown]
# # entropy

# %%
def entropy(p):
    ans = 0
    for i in range(len(p)):
        if p[i] > 0:
            ans -= p[i]*dlt * math.log2(p[i]*dlt)
    return ans

def D_KL(p,q):
    ans = 0
    for i in range(len(p)):
        ans += p[i]*dlt * math.log2(p[i]/q[i])
    return ans

def cross_entropy(p,q):
    return entropy(p) + D_KL(p,q)

# https://stats.stackexchange.com/questions/97938/calculate-the-kullback-leibler-divergence-in-practice
def D_CUSTOM(p, q):
    ans = 0
    for i in range(len(p)):
        if p[i] > 0 or q[i] > 0:
            ave = (p[i]+q[i])/2.0
            if p[i] > 0:
                ans += p[i]*dlt * math.log2(p[i]/ave)
            if q[i] > 0:
                ans += q[i]*dlt * math.log2(q[i]/ave)
    return ans/2.0

print('H(dist1): ' + str(entropy(dist1)))
print('H(dist2): ' + str(entropy(dist2)))
print('H(dist1;dist1): ' + str(cross_entropy(dist1, dist1)))
print('H(dist1;dist2): ' + str(cross_entropy(dist1, dist2)))
print('D_KL(dist1||dist1): ' + str(D_KL(dist1, dist1)))
print('D_KL(dist1||dist2): ' + str(D_KL(dist1, dist2)))

print('H(p_noise): ' + str(entropy(p_noise)))
# Out:
# H(dist1): 8.690936064948254
# H(dist2): 8.690936064948254
# H(dist1;dist1): 8.690936064948254
# H(dist1;dist2): 8.690936064948254
# D_KL(dist1||dist1): 0.0
# D_KL(dist1||dist2): 0.0
# H(p_noise): 6.953986180789161

# %% [markdown]
# # naive with noises

# %%
p1 = list(dist1)
p2 = list(dist2)

H1 = [entropy(p1)]
H11 = [D_CUSTOM(dist1, p1)]
H2 = [entropy(p2)]
H22 = [D_CUSTOM(dist2, p2)]
MAP1 = [np.argmax(p1)*dlt]
MAP2 = [np.argmax(p2)*dlt]

for i in range(n_interactions):
    p1_pass = conv(p1, p_noise, noise_mean_indx)
    p2_pass = conv(p2, p_noise, noise_mean_indx)
    noise = random.gauss(noise_mean, noise_sigma)
    p1 = combine(p1, p2_pass, int((noise-noise_mean)/dlt+0.5))
    p2 = combine(p2, p1_pass, int(-(noise-noise_mean)/dlt+0.5))
    
    H1 += [entropy(p1)]
    H11 += [D_CUSTOM(dist1, p1)]
    H2 += [entropy(p2)]
    H22 += [D_CUSTOM(dist2, p2)]
    MAP1 += [np.argmax(p1)*dlt]
    MAP2 += [np.argmax(p2)*dlt]

    if i % 5 == 0:
        print(str(i) + ' iterations done...')

print(sum(p1)*dlt)
print(sum(p2)*dlt)

plt.scatter(x_axis, p1)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(p1)*dlt))
plt.scatter(x_axis, p2)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(p2)*dlt))
# Out:
# 0 iterations done...
# 5 iterations done...
# 10 iterations done...
# 15 iterations done...
# 20 iterations done...
# 25 iterations done...
# 30 iterations done...
# 35 iterations done...
# 40 iterations done...
# 45 iterations done...
# 50 iterations done...
# 55 iterations done...
# 60 iterations done...
# 65 iterations done...
# 70 iterations done...
# 75 iterations done...
# 80 iterations done...
# 85 iterations done...
# 90 iterations done...
# 95 iterations done...
# 100 iterations done...
# 105 iterations done...
# 110 iterations done...
# 115 iterations done...
# 120 iterations done...
# 125 iterations done...
# 130 iterations done...
# 135 iterations done...
# 140 iterations done...
# 145 iterations done...
# 150 iterations done...
# 155 iterations done...
# 160 iterations done...
# 165 iterations done...
# 170 iterations done...
# 175 iterations done...
# 180 iterations done...
# 185 iterations done...
# 190 iterations done...
# 195 iterations done...
# 200 iterations done...
# 205 iterations done...
# 210 iterations done...
# 215 iterations done...
# 220 iterations done...
# 225 iterations done...
# 230 iterations done...
# 235 iterations done...
# 240 iterations done...
# 245 iterations done...
# 250 iterations done...
# 255 iterations done...
# 260 iterations done...
# 265 iterations done...
# 270 iterations done...
# 275 iterations done...
# 280 iterations done...
# 285 iterations done...
# 290 iterations done...
# 295 iterations done...
# 300 iterations done...
# 305 iterations done...
# 310 iterations done...
# 315 iterations done...
# 320 iterations done...
# 325 iterations done...
# 330 iterations done...
# 335 iterations done...
# 340 iterations done...
# 345 iterations done...
# 350 iterations done...
# 355 iterations done...
# 360 iterations done...
# 365 iterations done...
# 370 iterations done...
# 375 iterations done...
# 380 iterations done...
# 385 iterations done...
# 390 iterations done...
# 395 iterations done...
# 400 iterations done...
# 405 iterations done...
# 410 iterations done...
# 415 iterations done...
# 420 iterations done...
# 425 iterations done...
# 430 iterations done...
# 435 iterations done...
# 440 iterations done...
# 445 iterations done...
# 450 iterations done...
# 455 iterations done...
# 460 iterations done...
# 465 iterations done...
# 470 iterations done...
# 475 iterations done...
# 480 iterations done...
# 485 iterations done...
# 490 iterations done...
# 495 iterations done...
# 500 iterations done...
# 505 iterations done...
# 510 iterations done...
# 515 iterations done...
# 520 iterations done...
# 525 iterations done...
# 530 iterations done...
# 535 iterations done...
# 540 iterations done...
# 545 iterations done...
# 550 iterations done...
# 555 iterations done...
# 560 iterations done...
# 565 iterations done...
# 570 iterations done...
# 575 iterations done...
# 580 iterations done...
# 585 iterations done...
# 590 iterations done...
# 595 iterations done...
# 600 iterations done...
# 605 iterations done...
# 610 iterations done...
# 615 iterations done...
# 620 iterations done...
# 625 iterations done...
# 630 iterations done...
# 635 iterations done...
# 640 iterations done...
# 645 iterations done...
# 650 iterations done...
# 655 iterations done...
# 660 iterations done...
# 665 iterations done...
# 670 iterations done...
# 675 iterations done...
# 680 iterations done...
# 685 iterations done...
# 690 iterations done...
# 695 iterations done...
# 700 iterations done...
# 705 iterations done...
# 710 iterations done...
# 715 iterations done...
# 720 iterations done...
# 725 iterations done...
# 730 iterations done...
# 735 iterations done...
# 740 iterations done...
# 745 iterations done...
# 750 iterations done...
# 755 iterations done...
# 760 iterations done...
# 765 iterations done...
# 770 iterations done...
# 775 iterations done...
# 780 iterations done...
# 785 iterations done...
# 790 iterations done...
# 795 iterations done...
# 800 iterations done...
# 805 iterations done...
# 810 iterations done...
# 815 iterations done...
# 820 iterations done...
# 825 iterations done...
# 830 iterations done...
# 835 iterations done...
# 840 iterations done...
# 845 iterations done...
# 850 iterations done...
# 855 iterations done...
# 860 iterations done...
# 865 iterations done...
# 870 iterations done...
# 875 iterations done...
# 880 iterations done...
# 885 iterations done...
# 890 iterations done...
# 895 iterations done...
# 900 iterations done...
# 905 iterations done...
# 910 iterations done...
# 915 iterations done...
# 920 iterations done...
# 925 iterations done...
# 930 iterations done...
# 935 iterations done...
# 940 iterations done...
# 945 iterations done...
# 950 iterations done...
# 955 iterations done...
# 960 iterations done...
# 965 iterations done...
# 970 iterations done...
# 975 iterations done...
# 980 iterations done...
# 985 iterations done...
# 990 iterations done...
# 995 iterations done...
# 0.9999999999999997
# 0.9999999999999993
# max at 49.6
# max at 49.5

# %%
plt.plot(H1)
plt.ylabel('H(p1)')
print('min(H(p1)): ' + str(min(H1)))
plt.show()
plt.plot(H11)
plt.ylabel('D_CUSTOM(dist1;p1)')
plt.show()
plt.plot(H2)
plt.ylabel('H(p2)')
plt.show()
plt.plot(H22)
plt.ylabel('D_CUSTOM(dist2;p2)')
plt.show()
plt.plot(MAP1)
plt.ylabel('MAP1')
plt.show()
plt.plot(MAP2)
plt.ylabel('MAP2')
plt.show()
# Out:
# min(H(p1)): 1.9786621651691918

# %% [markdown]
# # Conservative with noises

# %%
p1 = list(dist1)
p2 = list(dist2)

H1 = [entropy(p1)]
H11 = [D_CUSTOM(dist1, p1)]
H2 = [entropy(p2)]
H22 = [D_CUSTOM(dist2, p2)]
MAP1 = [np.argmax(p1)*dlt]
MAP2 = [np.argmax(p2)*dlt]

omega = 0.95
for i in range(n_interactions):
    p1_omega, p1_1_omega = divide(p1, omega)
    p2_omega, p2_1_omega = divide(p2, omega)

    p1_to_pass = conv(p1_1_omega, p_noise, noise_mean_indx)
    p2_to_pass = conv(p2_1_omega, p_noise, noise_mean_indx)
    noise = random.gauss(noise_mean, noise_sigma)

    p1 = combine(p1_omega, p2_to_pass, int((noise-noise_mean)/dlt+0.5))
    p2 = combine(p2_omega, p1_to_pass, int(-(noise-noise_mean)/dlt+0.5))

    H1 += [entropy(p1)]
    H11 += [D_CUSTOM(dist1, p1)]
    H2 += [entropy(p2)]
    H22 += [D_CUSTOM(dist2, p2)]
    MAP1 += [np.argmax(p1)*dlt]
    MAP2 += [np.argmax(p2)*dlt]

    if i % 5 == 0:
        print(str(i) + ' iterations done...')

print(sum(p1)*dlt)
print(sum(p2)*dlt)
plt.scatter(x_axis, p1)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(p1)*dlt))
plt.scatter(x_axis, p2)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(p2)*dlt))
# Out:
# 0 iterations done...
# 5 iterations done...
# 10 iterations done...
# 15 iterations done...
# 20 iterations done...
# 25 iterations done...
# 30 iterations done...
# 35 iterations done...
# 40 iterations done...
# 45 iterations done...
# 50 iterations done...
# 55 iterations done...
# 60 iterations done...
# 65 iterations done...
# 70 iterations done...
# 75 iterations done...
# 80 iterations done...
# 85 iterations done...
# 90 iterations done...
# 95 iterations done...
# 100 iterations done...
# 105 iterations done...
# 110 iterations done...
# 115 iterations done...
# 120 iterations done...
# 125 iterations done...
# 130 iterations done...
# 135 iterations done...
# 140 iterations done...
# 145 iterations done...
# 150 iterations done...
# 155 iterations done...
# 160 iterations done...
# 165 iterations done...
# 170 iterations done...
# 175 iterations done...
# 180 iterations done...
# 185 iterations done...
# 190 iterations done...
# 195 iterations done...
# 200 iterations done...
# 205 iterations done...
# 210 iterations done...
# 215 iterations done...
# 220 iterations done...
# 225 iterations done...
# 230 iterations done...
# 235 iterations done...
# 240 iterations done...
# 245 iterations done...
# 250 iterations done...
# 255 iterations done...
# 260 iterations done...
# 265 iterations done...
# 270 iterations done...
# 275 iterations done...
# 280 iterations done...
# 285 iterations done...
# 290 iterations done...
# 295 iterations done...
# 300 iterations done...
# 305 iterations done...
# 310 iterations done...
# 315 iterations done...
# 320 iterations done...
# 325 iterations done...
# 330 iterations done...
# 335 iterations done...
# 340 iterations done...
# 345 iterations done...
# 350 iterations done...
# 355 iterations done...
# 360 iterations done...
# 365 iterations done...
# 370 iterations done...
# 375 iterations done...
# 380 iterations done...
# 385 iterations done...
# 390 iterations done...
# 395 iterations done...
# 400 iterations done...
# 405 iterations done...
# 410 iterations done...
# 415 iterations done...
# 420 iterations done...
# 425 iterations done...
# 430 iterations done...
# 435 iterations done...
# 440 iterations done...
# 445 iterations done...
# 450 iterations done...
# 455 iterations done...
# 460 iterations done...
# 465 iterations done...
# 470 iterations done...
# 475 iterations done...
# 480 iterations done...
# 485 iterations done...
# 490 iterations done...
# 495 iterations done...
# 500 iterations done...
# 505 iterations done...
# 510 iterations done...
# 515 iterations done...
# 520 iterations done...
# 525 iterations done...
# 530 iterations done...
# 535 iterations done...
# 540 iterations done...
# 545 iterations done...
# 550 iterations done...
# 555 iterations done...
# 560 iterations done...
# 565 iterations done...
# 570 iterations done...
# 575 iterations done...
# 580 iterations done...
# 585 iterations done...
# 590 iterations done...
# 595 iterations done...
# 600 iterations done...
# 605 iterations done...
# 610 iterations done...
# 615 iterations done...
# 620 iterations done...
# 625 iterations done...
# 630 iterations done...
# 635 iterations done...
# 640 iterations done...
# 645 iterations done...
# 650 iterations done...
# 655 iterations done...
# 660 iterations done...
# 665 iterations done...
# 670 iterations done...
# 675 iterations done...
# 680 iterations done...
# 685 iterations done...
# 690 iterations done...
# 695 iterations done...
# 700 iterations done...
# 705 iterations done...
# 710 iterations done...
# 715 iterations done...
# 720 iterations done...
# 725 iterations done...
# 730 iterations done...
# 735 iterations done...
# 740 iterations done...
# 745 iterations done...
# 750 iterations done...
# 755 iterations done...
# 760 iterations done...
# 765 iterations done...
# 770 iterations done...
# 775 iterations done...
# 780 iterations done...
# 785 iterations done...
# 790 iterations done...
# 795 iterations done...
# 800 iterations done...
# 805 iterations done...
# 810 iterations done...
# 815 iterations done...
# 820 iterations done...
# 825 iterations done...
# 830 iterations done...
# 835 iterations done...
# 840 iterations done...
# 845 iterations done...
# 850 iterations done...
# 855 iterations done...
# 860 iterations done...
# 865 iterations done...
# 870 iterations done...
# 875 iterations done...
# 880 iterations done...
# 885 iterations done...
# 890 iterations done...
# 895 iterations done...
# 900 iterations done...
# 905 iterations done...
# 910 iterations done...
# 915 iterations done...
# 920 iterations done...
# 925 iterations done...
# 930 iterations done...
# 935 iterations done...
# 940 iterations done...
# 945 iterations done...
# 950 iterations done...
# 955 iterations done...
# 960 iterations done...
# 965 iterations done...
# 970 iterations done...
# 975 iterations done...
# 980 iterations done...
# 985 iterations done...
# 990 iterations done...
# 995 iterations done...
# 0.9999999999999982
# 1.0000000000000007
# max at 48.6
# max at 47.5

# %%
plt.plot(H1)
plt.ylabel('H(p1)')
print('min(H(p1)): ' + str(min(H1)))
plt.show()
plt.plot(H11)
plt.ylabel('D_CUSTOM(dist1;p1)')
plt.show()
plt.plot(H2)
plt.ylabel('H(p2)')
plt.show()
plt.plot(H22)
plt.ylabel('D_CUSTOM(dist2;p2)')
plt.show()
plt.plot(MAP1)
plt.ylabel('MAP1')
plt.show()
plt.plot(MAP2)
plt.ylabel('MAP2')
plt.show()
# Out:
# min(H(p1)): 7.953626509952595

# %% [markdown]
# # Conservative with noise (dividing noise)

# %%
p1 = list(dist1)
p2 = list(dist2)
H1 = [entropy(p1)]
H11 = [D_CUSTOM(dist1, p1)]
H2 = [entropy(p2)]
H22 = [D_CUSTOM(dist2, p2)]
MAP1 = [np.argmax(p1)*dlt]
MAP2 = [np.argmax(p2)*dlt]

omega = 0.95
for i in range(n_interactions):
    p1_omega, p1_1_omega = divide(p1, omega)
    p2_omega, p2_1_omega = divide(p2, omega)
    
    p_noise_div, p_noise_div2 = divide(p_noise, 1 - omega)
    p1_to_pass = conv(p1_1_omega, p_noise_div, noise_mean_indx)
    p2_to_pass = conv(p2_1_omega, p_noise_div, noise_mean_indx)
#     p1_to_pass = conv(p1, p_noise, noise_mean_indx)
#     p1_to_discard, p1_to_pass = divide(p1_to_pass, omega)
#     p2_to_pass = conv(p2, p_noise, noise_mean_indx)
#     p2_to_discard, p2_to_pass = divide(p2_to_pass, omega)
    noise = random.gauss(noise_mean, noise_sigma)

    p1 = combine(p1_omega, p2_to_pass, int((noise-noise_mean)/dlt+0.5))
    p2 = combine(p2_omega, p1_to_pass, int(-(noise-noise_mean)/dlt+0.5))

    H1 += [entropy(p1)]
    H11 += [D_CUSTOM(dist1, p1)]
    H2 += [entropy(p2)]
    H22 += [D_CUSTOM(dist2, p2)]
    MAP1 += [np.argmax(p1)*dlt]
    MAP2 += [np.argmax(p2)*dlt]

    if i % 5 == 0:
        print(str(i) + ' iterations done...')

print(sum(p1)*dlt)
print(sum(p2)*dlt)
plt.scatter(x_axis, p1)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(p1)*dlt))
plt.scatter(x_axis, p2)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(p2)*dlt))
# Out:
# 0 iterations done...
# 5 iterations done...
# 10 iterations done...
# 15 iterations done...
# 20 iterations done...
# 25 iterations done...
# 30 iterations done...
# 35 iterations done...
# 40 iterations done...
# 45 iterations done...
# 50 iterations done...
# 55 iterations done...
# 60 iterations done...
# 65 iterations done...
# 70 iterations done...
# 75 iterations done...
# 80 iterations done...
# 85 iterations done...
# 90 iterations done...
# 95 iterations done...
# 100 iterations done...
# 105 iterations done...
# 110 iterations done...
# 115 iterations done...
# 120 iterations done...
# 125 iterations done...
# 130 iterations done...
# 135 iterations done...
# 140 iterations done...
# 145 iterations done...
# 150 iterations done...
# 155 iterations done...
# 160 iterations done...
# 165 iterations done...
# 170 iterations done...
# 175 iterations done...
# 180 iterations done...
# 185 iterations done...
# 190 iterations done...
# 195 iterations done...
# 200 iterations done...
# 205 iterations done...
# 210 iterations done...
# 215 iterations done...
# 220 iterations done...
# 225 iterations done...
# 230 iterations done...
# 235 iterations done...
# 240 iterations done...
# 245 iterations done...
# 250 iterations done...
# 255 iterations done...
# 260 iterations done...
# 265 iterations done...
# 270 iterations done...
# 275 iterations done...
# 280 iterations done...
# 285 iterations done...
# 290 iterations done...
# 295 iterations done...
# 300 iterations done...
# 305 iterations done...
# 310 iterations done...
# 315 iterations done...
# 320 iterations done...
# 325 iterations done...
# 330 iterations done...
# 335 iterations done...
# 340 iterations done...
# 345 iterations done...
# 350 iterations done...
# 355 iterations done...
# 360 iterations done...
# 365 iterations done...
# 370 iterations done...
# 375 iterations done...
# 380 iterations done...
# 385 iterations done...
# 390 iterations done...
# 395 iterations done...
# 400 iterations done...
# 405 iterations done...
# 410 iterations done...
# 415 iterations done...
# 420 iterations done...
# 425 iterations done...
# 430 iterations done...
# 435 iterations done...
# 440 iterations done...
# 445 iterations done...
# 450 iterations done...
# 455 iterations done...
# 460 iterations done...
# 465 iterations done...
# 470 iterations done...
# 475 iterations done...
# 480 iterations done...
# 485 iterations done...
# 490 iterations done...
# 495 iterations done...
# 500 iterations done...
# 505 iterations done...
# 510 iterations done...
# 515 iterations done...
# 520 iterations done...
# 525 iterations done...
# 530 iterations done...
# 535 iterations done...
# 540 iterations done...
# 545 iterations done...
# 550 iterations done...
# 555 iterations done...
# 560 iterations done...
# 565 iterations done...
# 570 iterations done...
# 575 iterations done...
# 580 iterations done...
# 585 iterations done...
# 590 iterations done...
# 595 iterations done...
# 600 iterations done...
# 605 iterations done...
# 610 iterations done...
# 615 iterations done...
# 620 iterations done...
# 625 iterations done...
# 630 iterations done...
# 635 iterations done...
# 640 iterations done...
# 645 iterations done...
# 650 iterations done...
# 655 iterations done...
# 660 iterations done...
# 665 iterations done...
# 670 iterations done...
# 675 iterations done...
# 680 iterations done...
# 685 iterations done...
# 690 iterations done...
# 695 iterations done...
# 700 iterations done...
# 705 iterations done...
# 710 iterations done...
# 715 iterations done...
# 720 iterations done...
# 725 iterations done...
# 730 iterations done...
# 735 iterations done...
# 740 iterations done...
# 745 iterations done...
# 750 iterations done...
# 755 iterations done...
# 760 iterations done...
# 765 iterations done...
# 770 iterations done...
# 775 iterations done...
# 780 iterations done...
# 785 iterations done...
# 790 iterations done...
# 795 iterations done...
# 800 iterations done...
# 805 iterations done...
# 810 iterations done...
# 815 iterations done...
# 820 iterations done...
# 825 iterations done...
# 830 iterations done...
# 835 iterations done...
# 840 iterations done...
# 845 iterations done...
# 850 iterations done...
# 855 iterations done...
# 860 iterations done...
# 865 iterations done...
# 870 iterations done...
# 875 iterations done...
# 880 iterations done...
# 885 iterations done...
# 890 iterations done...
# 895 iterations done...
# 900 iterations done...
# 905 iterations done...
# 910 iterations done...
# 915 iterations done...
# 920 iterations done...
# 925 iterations done...
# 930 iterations done...
# 935 iterations done...
# 940 iterations done...
# 945 iterations done...
# 950 iterations done...
# 955 iterations done...
# 960 iterations done...
# 965 iterations done...
# 970 iterations done...
# 975 iterations done...
# 980 iterations done...
# 985 iterations done...
# 990 iterations done...
# 995 iterations done...
# 0.9999999999999996
# 0.9999999999999979
# max at 49.7
# max at 49.400000000000006

# %%
plt.plot(H1)
plt.ylabel('H(p1)')
print('min(H(p1)): ' + str(min(H1)))
plt.show()
plt.plot(H11)
plt.ylabel('D_CUSTOM(dist1;p1)')
plt.show()
plt.plot(H2)
plt.ylabel('H(p2)')
plt.show()
plt.plot(H22)
plt.ylabel('D_CUSTOM(dist2;p2)')
plt.show()
plt.plot(MAP1)
plt.ylabel('MAP1')
plt.show()
plt.plot(MAP2)
plt.ylabel('MAP2')
plt.show()
# Out:
# min(H(p1)): 8.35553930525753

# %% [markdown]
# # Conservative with noise (but noise is ignored for est)

# %%
p1 = list(dist1)
p2 = list(dist2)
H1 = [entropy(p1)]
H11 = [D_CUSTOM(dist1, p1)]
H2 = [entropy(p2)]
H22 = [D_CUSTOM(dist2, p2)]
MAP1 = [np.argmax(p1)*dlt]
MAP2 = [np.argmax(p2)*dlt]

omega = 0.95
for i in range(n_interactions):
    p1_omega, p1_1_omega = divide(p1, omega)
    p2_omega, p2_1_omega = divide(p2, omega)
    
    
    p1_to_pass = p1_1_omega #conv(p1_1_omega, p_noise2, noise_mean_indx)
    p2_to_pass = p2_1_omega #conv(p2_1_omega, p_noise2, noise_mean_indx)
    noise = random.gauss(noise_mean, noise_sigma)

    p1 = combine(p1_omega, p2_to_pass, int((noise-noise_mean)/dlt+0.5))
    p2 = combine(p2_omega, p1_to_pass, int(-(noise-noise_mean)/dlt+0.5))

    H1 += [entropy(p1)]
    H11 += [D_CUSTOM(dist1, p1)]
    H2 += [entropy(p2)]
    H22 += [D_CUSTOM(dist2, p2)]
    MAP1 += [np.argmax(p1)*dlt]
    MAP2 += [np.argmax(p2)*dlt]

    if i % 5 == 0:
        print(str(i) + ' iterations done...')

print(sum(p1)*dlt)
print(sum(p2)*dlt)
plt.scatter(x_axis, p1)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(p1)*dlt))
plt.scatter(x_axis, p2)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(p2)*dlt))
# Out:
# 0 iterations done...
# 5 iterations done...
# 10 iterations done...
# 15 iterations done...
# 20 iterations done...
# 25 iterations done...
# 30 iterations done...
# 35 iterations done...
# 40 iterations done...
# 45 iterations done...
# 50 iterations done...
# 55 iterations done...
# 60 iterations done...
# 65 iterations done...
# 70 iterations done...
# 75 iterations done...
# 80 iterations done...
# 85 iterations done...
# 90 iterations done...
# 95 iterations done...
# 100 iterations done...
# 105 iterations done...
# 110 iterations done...
# 115 iterations done...
# 120 iterations done...
# 125 iterations done...
# 130 iterations done...
# 135 iterations done...
# 140 iterations done...
# 145 iterations done...
# 150 iterations done...
# 155 iterations done...
# 160 iterations done...
# 165 iterations done...
# 170 iterations done...
# 175 iterations done...
# 180 iterations done...
# 185 iterations done...
# 190 iterations done...
# 195 iterations done...
# 200 iterations done...
# 205 iterations done...
# 210 iterations done...
# 215 iterations done...
# 220 iterations done...
# 225 iterations done...
# 230 iterations done...
# 235 iterations done...
# 240 iterations done...
# 245 iterations done...
# 250 iterations done...
# 255 iterations done...
# 260 iterations done...
# 265 iterations done...
# 270 iterations done...
# 275 iterations done...
# 280 iterations done...
# 285 iterations done...
# 290 iterations done...
# 295 iterations done...
# 300 iterations done...
# 305 iterations done...
# 310 iterations done...
# 315 iterations done...
# 320 iterations done...
# 325 iterations done...
# 330 iterations done...
# 335 iterations done...
# 340 iterations done...
# 345 iterations done...
# 350 iterations done...
# 355 iterations done...
# 360 iterations done...
# 365 iterations done...
# 370 iterations done...
# 375 iterations done...
# 380 iterations done...
# 385 iterations done...
# 390 iterations done...
# 395 iterations done...
# 400 iterations done...
# 405 iterations done...
# 410 iterations done...
# 415 iterations done...
# 420 iterations done...
# 425 iterations done...
# 430 iterations done...
# 435 iterations done...
# 440 iterations done...
# 445 iterations done...
# 450 iterations done...
# 455 iterations done...
# 460 iterations done...
# 465 iterations done...
# 470 iterations done...
# 475 iterations done...
# 480 iterations done...
# 485 iterations done...
# 490 iterations done...
# 495 iterations done...
# 500 iterations done...
# 505 iterations done...
# 510 iterations done...
# 515 iterations done...
# 520 iterations done...
# 525 iterations done...
# 530 iterations done...
# 535 iterations done...
# 540 iterations done...
# 545 iterations done...
# 550 iterations done...
# 555 iterations done...
# 560 iterations done...
# 565 iterations done...
# 570 iterations done...
# 575 iterations done...
# 580 iterations done...
# 585 iterations done...
# 590 iterations done...
# 595 iterations done...
# 600 iterations done...
# 605 iterations done...
# 610 iterations done...
# 615 iterations done...
# 620 iterations done...
# 625 iterations done...
# 630 iterations done...
# 635 iterations done...
# 640 iterations done...
# 645 iterations done...
# 650 iterations done...
# 655 iterations done...
# 660 iterations done...
# 665 iterations done...
# 670 iterations done...
# 675 iterations done...
# 680 iterations done...
# 685 iterations done...
# 690 iterations done...
# 695 iterations done...
# 700 iterations done...
# 705 iterations done...
# 710 iterations done...
# 715 iterations done...
# 720 iterations done...
# 725 iterations done...
# 730 iterations done...
# 735 iterations done...
# 740 iterations done...
# 745 iterations done...
# 750 iterations done...
# 755 iterations done...
# 760 iterations done...
# 765 iterations done...
# 770 iterations done...
# 775 iterations done...
# 780 iterations done...
# 785 iterations done...
# 790 iterations done...
# 795 iterations done...
# 800 iterations done...
# 805 iterations done...
# 810 iterations done...
# 815 iterations done...
# 820 iterations done...
# 825 iterations done...
# 830 iterations done...
# 835 iterations done...
# 840 iterations done...
# 845 iterations done...
# 850 iterations done...
# 855 iterations done...
# 860 iterations done...
# 865 iterations done...
# 870 iterations done...
# 875 iterations done...
# 880 iterations done...
# 885 iterations done...
# 890 iterations done...
# 895 iterations done...
# 900 iterations done...
# 905 iterations done...
# 910 iterations done...
# 915 iterations done...
# 920 iterations done...
# 925 iterations done...
# 930 iterations done...
# 935 iterations done...
# 940 iterations done...
# 945 iterations done...
# 950 iterations done...
# 955 iterations done...
# 960 iterations done...
# 965 iterations done...
# 970 iterations done...
# 975 iterations done...
# 980 iterations done...
# 985 iterations done...
# 990 iterations done...
# 995 iterations done...
# 0.9999999999999981
# 1.0000000000000013
# max at 48.1
# max at 46.900000000000006

# %%
plt.plot(H1)
plt.ylabel('H(p1)')
print('min(H(p1)): ' + str(min(H1)))
plt.show()
plt.plot(H11)
plt.ylabel('D_CUSTOM(dist1;p1)')
plt.show()
plt.plot(H2)
plt.ylabel('H(p2)')
plt.show()
plt.plot(H22)
plt.ylabel('D_CUSTOM(dist2;p2)')
plt.show()
plt.plot(MAP1)
plt.ylabel('MAP1')
plt.show()
plt.plot(MAP2)
plt.ylabel('MAP2')
plt.show()
# Out:
# min(H(p1)): 8.690936064948254

# %% [markdown]
# # CI

# %%
p1 = list(dist1)
p2 = list(dist2)

H1 = [entropy(p1)]
H11 = [D_CUSTOM(dist1, p1)]
H2 = [entropy(p2)]
H22 = [D_CUSTOM(dist2, p2)]
MAP1 = [np.argmax(p1)*dlt]
MAP2 = [np.argmax(p2)*dlt]

def shift(p, off = 0):
    ans = []
    for i in range(len(p)):
        if i + off < 0:
            ans.append(p[0])
        elif len(p) <= i + off:
            ans.append(p[-1])
        else:
            ans.append(p[i+off])
    total = sum(ans)*dlt
    for i in range(len(ans)):
        ans[i] /= total
    return ans

for i in range(n_interactions):
    noise = random.gauss(noise_mean, noise_sigma)
    p1_pass = shift(conv(p1, p_noise, noise_mean_indx), int((noise-noise_mean)/dlt+0.5))
    p2_pass = shift(conv(p2, p_noise, noise_mean_indx), int(-(noise-noise_mean)/dlt+0.5))
    
    if entropy(p1) > entropy(p2_pass):
        p1 = p2_pass
    if entropy(p2) > entropy(p1_pass):
        p2 = p1_pass
    
    H1 += [entropy(p1)]
    H11 += [D_CUSTOM(dist1, p1)]
    H2 += [entropy(p2)]
    H22 += [D_CUSTOM(dist2, p2)]
    MAP1 += [np.argmax(p1)*dlt]
    MAP2 += [np.argmax(p2)*dlt]

    if i % 5 == 0:
        print(str(i) + ' iterations done...')

print(sum(p1)*dlt)
print(sum(p2)*dlt)

plt.scatter(x_axis, p1)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(p1)*dlt))
plt.scatter(x_axis, p2)
plt.xlim(x_min, x_max)
plt.show()
print("max at " + str(np.argmax(p2)*dlt))
# Out:
# 0 iterations done...
# 5 iterations done...
# 10 iterations done...
# 15 iterations done...
# 20 iterations done...
# 25 iterations done...
# 30 iterations done...
# 35 iterations done...
# 40 iterations done...
# 45 iterations done...
# 50 iterations done...
# 55 iterations done...
# 60 iterations done...
# 65 iterations done...
# 70 iterations done...
# 75 iterations done...
# 80 iterations done...
# 85 iterations done...
# 90 iterations done...
# 95 iterations done...
# 100 iterations done...
# 105 iterations done...
# 110 iterations done...
# 115 iterations done...
# 120 iterations done...
# 125 iterations done...
# 130 iterations done...
# 135 iterations done...
# 140 iterations done...
# 145 iterations done...
# 150 iterations done...
# 155 iterations done...
# 160 iterations done...
# 165 iterations done...
# 170 iterations done...
# 175 iterations done...
# 180 iterations done...
# 185 iterations done...
# 190 iterations done...
# 195 iterations done...
# 200 iterations done...
# 205 iterations done...
# 210 iterations done...
# 215 iterations done...
# 220 iterations done...
# 225 iterations done...
# 230 iterations done...
# 235 iterations done...
# 240 iterations done...
# 245 iterations done...
# 250 iterations done...
# 255 iterations done...
# 260 iterations done...
# 265 iterations done...
# 270 iterations done...
# 275 iterations done...
# 280 iterations done...
# 285 iterations done...
# 290 iterations done...
# 295 iterations done...
# 300 iterations done...
# 305 iterations done...
# 310 iterations done...
# 315 iterations done...
# 320 iterations done...
# 325 iterations done...
# 330 iterations done...
# 335 iterations done...
# 340 iterations done...
# 345 iterations done...
# 350 iterations done...
# 355 iterations done...
# 360 iterations done...
# 365 iterations done...
# 370 iterations done...
# 375 iterations done...
# 380 iterations done...
# 385 iterations done...
# 390 iterations done...
# 395 iterations done...
# 400 iterations done...
# 405 iterations done...
# 410 iterations done...
# 415 iterations done...
# 420 iterations done...
# 425 iterations done...
# 430 iterations done...
# 435 iterations done...
# 440 iterations done...
# 445 iterations done...
# 450 iterations done...
# 455 iterations done...
# 460 iterations done...
# 465 iterations done...
# 470 iterations done...
# 475 iterations done...
# 480 iterations done...
# 485 iterations done...
# 490 iterations done...
# 495 iterations done...
# 500 iterations done...
# 505 iterations done...
# 510 iterations done...
# 515 iterations done...
# 520 iterations done...
# 525 iterations done...
# 530 iterations done...
# 535 iterations done...
# 540 iterations done...
# 545 iterations done...
# 550 iterations done...
# 555 iterations done...
# 560 iterations done...
# 565 iterations done...
# 570 iterations done...
# 575 iterations done...
# 580 iterations done...
# 585 iterations done...
# 590 iterations done...
# 595 iterations done...
# 600 iterations done...
# 605 iterations done...
# 610 iterations done...
# 615 iterations done...
# 620 iterations done...
# 625 iterations done...
# 630 iterations done...
# 635 iterations done...
# 640 iterations done...
# 645 iterations done...
# 650 iterations done...
# 655 iterations done...
# 660 iterations done...
# 665 iterations done...
# 670 iterations done...
# 675 iterations done...
# 680 iterations done...
# 685 iterations done...
# 690 iterations done...
# 695 iterations done...
# 700 iterations done...
# 705 iterations done...
# 710 iterations done...
# 715 iterations done...
# 720 iterations done...
# 725 iterations done...
# 730 iterations done...
# 735 iterations done...
# 740 iterations done...
# 745 iterations done...
# 750 iterations done...
# 755 iterations done...
# 760 iterations done...
# 765 iterations done...
# 770 iterations done...
# 775 iterations done...
# 780 iterations done...
# 785 iterations done...
# 790 iterations done...
# 795 iterations done...
# 800 iterations done...
# 805 iterations done...
# 810 iterations done...
# 815 iterations done...
# 820 iterations done...
# 825 iterations done...
# 830 iterations done...
# 835 iterations done...
# 840 iterations done...
# 845 iterations done...
# 850 iterations done...
# 855 iterations done...
# 860 iterations done...
# 865 iterations done...
# 870 iterations done...
# 875 iterations done...
# 880 iterations done...
# 885 iterations done...
# 890 iterations done...
# 895 iterations done...
# 900 iterations done...
# 905 iterations done...
# 910 iterations done...
# 915 iterations done...
# 920 iterations done...
# 925 iterations done...
# 930 iterations done...
# 935 iterations done...
# 940 iterations done...
# 945 iterations done...
# 950 iterations done...
# 955 iterations done...
# 960 iterations done...
# 965 iterations done...
# 970 iterations done...
# 975 iterations done...
# 980 iterations done...
# 985 iterations done...
# 990 iterations done...
# 995 iterations done...
# 0.9999994265729685
# 0.9999994265729685
# max at 50.0
# max at 50.0

# %%
plt.plot(H1)
plt.ylabel('H(p1)')
print('min(H(p1)): ' + str(min(H1)))
plt.show()
plt.plot(H11)
plt.ylabel('D_CUSTOM(dist1;p1)')
plt.show()
plt.plot(H2)
plt.ylabel('H(p2)')
plt.show()
plt.plot(H22)
plt.ylabel('D_CUSTOM(dist2;p2)')
plt.show()
plt.plot(MAP1)
plt.ylabel('MAP1')
plt.show()
plt.plot(MAP2)
plt.ylabel('MAP2')
plt.show()
# Out:
# min(H(p1)): 8.690936064948254
